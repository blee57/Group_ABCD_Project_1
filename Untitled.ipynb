# %%
import pandas as pd

# %%
df = pd.read_csv('usa_00005.csv')
df
# Out:
#           YEAR  MULTYEAR  DATANUM   SERIAL       CBSERIAL  HHWT  STATEFIP  \
# 0         2016      2012        5        1  2012000000002     3         5
# 1         2016      2012        5        2  2012000000009    22        13
# 2         2016      2012        5        2  2012000000009    22        13
# 3         2016      2012        5        3  2012000000010    22        13
# 4         2016      2012        5        3  2012000000010    22        13
# ...        ...       ...      ...      ...            ...   ...       ...
# 15681922  2016      2016        5  6838804  2016001521445     6        47
# 15681923  2016      2016        5  6838804  2016001521445     6        47
# 15681924  2016      2016        5  6838804  2016001521445     6        47
# 15681925  2016      2016        5  6838804  2016001521445     6        47
# 15681926  2016      2016        5  6838804  2016001521445     6        47
#
#           COUNTYFIP  PUMA  GQ  OWNERSHP  OWNERSHPD  PERNUM  PERWT  SEX  AGE  \
# ...

# %%
df.columns
# Out:
# Index(['YEAR', 'MULTYEAR', 'DATANUM', 'SERIAL', 'CBSERIAL', 'HHWT', 'STATEFIP',
#        'COUNTYFIP', 'PUMA', 'GQ', 'OWNERSHP', 'OWNERSHPD', 'PERNUM', 'PERWT',
#        'SEX', 'AGE', 'RACE', 'RACED', 'HISPAN', 'HISPAND'],
#       dtype='object')
