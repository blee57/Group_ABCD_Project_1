# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import os
import csv

csvpath = os.path.join('data_export','revenue_district.csv')
expenditure_data = pd.read_csv(csvpath)

# %% [markdown]
# # Create a summar table for public school zipcodes

# %%
# load the excel into pandas
df_enrollment = pd.read_excel('dataset/C11_FY2019_HS Graduates 2017_Enrolled in College in 16 Mos_Redacted (2).xlsx')

# %%
# setting up the correct column names
# isolate the datapoints that we are interested in
all_school = df_enrollment.iloc[:,0:7].iloc[1:,]
# set new vlaues for columns
all_school.columns = all_school.iloc[0]
# remove the duplicate column names and reset the index
all_school = all_school.loc[2:,:].reset_index(drop = True)

# %%
# create df for aggregate information on all the schoool districts
school_all = all_school.loc[all_school['School Code'] == 'ALL']
# create df for the individual school codes
school_district = all_school.loc[all_school['School Code'] != 'ALL']
school_district
# Out:
# 1   School Year School District Code            School District Name  \
# 0          2017                  601                  Appling County
# 2          2017                  602                 Atkinson County
# 4          2017                  603                    Bacon County
# 6          2017                  604                    Baker County
# 8          2017                  605                  Baldwin County
# ..          ...                  ...                             ...
# 627        2017                  891  Department of Juvenile Justice
# 628        2017                  891  Department of Juvenile Justice
# 629        2017                  891  Department of Juvenile Justice
# 630        2017                  891  Department of Juvenile Justice
# 631        2017                  891  Department of Juvenile Justice
#
# 1   School Code                       School Name Total High School Graduates  \
# 0           103        Appling County High School                         198
# 2           103       Atkinson County High School                          97
# 4           302          Bacon County High School                         118
# 6           105           Baker County K12 School                          18
# 8           189               Baldwin High School                         271
# ..          ...                               ...                         ...
# 627         298  Augusta Youth Development Campus                         TFS
# 628         598    Macon Youth Development Campus                         TFS
# 629         898  Eastman Youth Development Campus                         TFS
# 630        4199                  Millegeville ITU                         TFS
# 631        5001   Sumter Youth Development Campus                         TFS
#
# 1   Number of High School Graduates Enrolled in Postsecondary Institution
# 0                                                  118
# 2                                                   60
# 4                                                   66
# 6                                                  TFS
# 8                                                  171
# ..                                                 ...
# 627                                                TFS
# 628                                                TFS
# 629                                                TFS
# 630                                                TFS
# 631                                                TFS
#
# [443 rows x 7 columns]

# %%
# identify the performance metrics that we want to use for analysis
performance_metrics = school_all[['School District Code','Total High School Graduates','Number of High School Graduates Enrolled in Postsecondary Institution']]
performance_metrics
# Out:
# 1   School District Code Total High School Graduates  \
# 1                    601                         198
# 3                    602                          97
# 5                    603                         118
# 7                    604                          18
# 9                    605                         271
# ..                   ...                         ...
# 621                  793                         167
# 623              7991893                         TFS
# 625              7991895                         TFS
# 632                  891                          20
# 633                  ALL                      106934
#
# 1   Number of High School Graduates Enrolled in Postsecondary Institution
# 1                                                  118
# 3                                                   60
# 5                                                   66
# 7                                                  TFS
# 9                                                  171
# ..                                                 ...
# 621                                                114
# 623                                                TFS
# 625                                                TFS
# 632                                                 10
# 633                                              72472
#
# [191 rows x 3 columns]

# %%
#create a backup 
school_all.to_csv('data_export/school_all.csv',index=False)
df = school_all.copy()

# %%
# reorganize the dataframe for the columns
df.columns = ['School Year', 'School District Code', 'School District Name',
       'School Code', 'School Name', 'Graduates',
       'Postsecondary Institution']

df
# Out:
#     School Year School District Code  \
# 1          2017                  601
# 3          2017                  602
# 5          2017                  603
# 7          2017                  604
# 9          2017                  605
# ..          ...                  ...
# 621        2017                  793
# 623        2017              7991893
# 625        2017              7991895
# 632        2017                  891
# 633        2017                  ALL
#
#                                 School District Name School Code  School Name  \
# 1                                     Appling County         ALL  All Schools
# 3                                    Atkinson County         ALL  All Schools
# 5                                       Bacon County         ALL  All Schools
# 7                                       Baker County         ALL  All Schools
# 9                                     Baldwin County         ALL  All Schools
# ..                                               ...         ...          ...
# 621                                     Vidalia City         ALL  All Schools
# 623  State Schools- Atlanta Area School for the Deaf         ALL  All Schools
# 625       State Schools- Georgia School for the Deaf         ALL  All Schools
# 632                   Department of Juvenile Justice         ALL  All Schools
# 633                                      All Systems         ALL  All Schools
#
#     Graduates Postsecondary Institution
# 1         198                       118
# 3          97                        60
# 5         118                        66
# 7          18                       TFS
# 9         271                       171
# ..        ...                       ...
# 621       167                       114
# 623       TFS                       TFS
# 625       TFS                       TFS
# 632        20                        10
# 633    106934                     72472
#
# [191 rows x 7 columns]

# %%
# drop all the rows where there are anhy value "TFS" in the cells
school_no_TFS = df.replace('TFS', np.nan).dropna()
school_no_TFS
# Out:
#      School Year School District Code            School District Name  \
# 1           2017                  601                  Appling County
# 3           2017                  602                 Atkinson County
# 5           2017                  603                    Bacon County
# 9           2017                  605                  Baldwin County
# 11          2017                  606                    Banks County
# ..           ...                  ...                             ...
# 617         2017                  791                      Trion City
# 619         2017                  792                   Valdosta City
# 621         2017                  793                    Vidalia City
# 632         2017                  891  Department of Juvenile Justice
# 633         2017                  ALL                     All Systems
#
#     School Code  School Name  Graduates  Postsecondary Institution
# 1           ALL  All Schools      198.0                      118.0
# 3           ALL  All Schools       97.0                       60.0
# 5           ALL  All Schools      118.0                       66.0
# 9           ALL  All Schools      271.0                      171.0
# 11          ALL  All Schools      209.0                      108.0
# ..          ...          ...        ...                        ...
# 617         ALL  All Schools       88.0                       69.0
# 619         ALL  All Schools      374.0                      247.0
# 621         ALL  All Schools      167.0                      114.0
# 632         ALL  All Schools       20.0                       10.0
# 633         ALL  All Schools   106934.0                    72472.0
#
# [186 rows x 7 columns]

# %%
# reset the index for the dataframe
school_no_TFS = school_no_TFS.reset_index(drop=True)
# remove the aggregate School District Code data at the end of the dataset
school_no_TFS = school_no_TFS.iloc[:185]
school_no_TFS
# Out:
#      School Year School District Code            School District Name  \
# 0           2017                  601                  Appling County
# 1           2017                  602                 Atkinson County
# 2           2017                  603                    Bacon County
# 3           2017                  605                  Baldwin County
# 4           2017                  606                    Banks County
# ..           ...                  ...                             ...
# 180         2017                  789                Thomasville City
# 181         2017                  791                      Trion City
# 182         2017                  792                   Valdosta City
# 183         2017                  793                    Vidalia City
# 184         2017                  891  Department of Juvenile Justice
#
#     School Code  School Name  Graduates  Postsecondary Institution
# 0           ALL  All Schools      198.0                      118.0
# 1           ALL  All Schools       97.0                       60.0
# 2           ALL  All Schools      118.0                       66.0
# 3           ALL  All Schools      271.0                      171.0
# 4           ALL  All Schools      209.0                      108.0
# ..          ...          ...        ...                        ...
# 180         ALL  All Schools      155.0                      123.0
# 181         ALL  All Schools       88.0                       69.0
# 182         ALL  All Schools      374.0                      247.0
# 183         ALL  All Schools      167.0                      114.0
# 184         ALL  All Schools       20.0                       10.0
#
# [185 rows x 7 columns]

# %%
# create a column for the percentage of students that went to college after graduation
percent = (school_no_TFS['Postsecondary Institution'] / school_no_TFS['Graduates']*100).round(2)
school_no_TFS['Percent'] = percent
school_no_TFS
# Out:
#      School Year School District Code            School District Name  \
# 0           2017                  601                  Appling County
# 1           2017                  602                 Atkinson County
# 2           2017                  603                    Bacon County
# 3           2017                  605                  Baldwin County
# 4           2017                  606                    Banks County
# ..           ...                  ...                             ...
# 180         2017                  789                Thomasville City
# 181         2017                  791                      Trion City
# 182         2017                  792                   Valdosta City
# 183         2017                  793                    Vidalia City
# 184         2017                  891  Department of Juvenile Justice
#
#     School Code  School Name  Graduates  Postsecondary Institution  Percent
# 0           ALL  All Schools      198.0                      118.0    59.60
# 1           ALL  All Schools       97.0                       60.0    61.86
# 2           ALL  All Schools      118.0                       66.0    55.93
# 3           ALL  All Schools      271.0                      171.0    63.10
# 4           ALL  All Schools      209.0                      108.0    51.67
# ..          ...          ...        ...                        ...      ...
# 180         ALL  All Schools      155.0                      123.0    79.35
# 181         ALL  All Schools       88.0                       69.0    78.41
# 182         ALL  All Schools      374.0                      247.0    66.04
# 183         ALL  All Schools      167.0                      114.0    68.26
# 184         ALL  All Schools       20.0                       10.0    50.00
#
# [185 rows x 8 columns]

# %%
# generate the bar graph of college enrollment percentage per county
school_no_TFS.plot.bar(x='School District Code', y='Percent', figsize = (40,5))
# Out:
# <AxesSubplot:xlabel='School District Code'>

# %%
school_no_TFS = school_no_TFS.loc[school_no_TFS['School District Code']<1000]

# %%
school_sorted = school_no_TFS.sort_values('Percent', ascending = False)

# %%
school_sorted.head()
# Out:
#      School Year School District Code School District Name School Code  \
# 105         2017                  708        Oconee County         ALL
# 164         2017                  773         Decatur City         ALL
# 53          2017                  656       Fayette County         ALL
# 55          2017                  658       Forsyth County         ALL
# 157         2017                  764          Buford City         ALL
#
#      School Name  Graduates  Postsecondary Institution  Percent
# 105  All Schools      553.0                      491.0    88.79
# 164  All Schools      254.0                      221.0    87.01
# 53   All Schools     1575.0                     1312.0    83.30
# 55   All Schools     3020.0                     2502.0    82.85
# 157  All Schools      269.0                      218.0    81.04

# %%
school_sorted.sort_values('Percent').head()
# Out:
#     School Year School District Code School District Name School Code  \
# 25         2017                  627     Chattooga County         ALL
# 38         2017                  641          Dade County         ALL
# 96         2017                  699    Meriwether County         ALL
# 68         2017                  671      Haralson County         ALL
# 43         2017                  646         Dooly County         ALL
#
#     School Name  Graduates  Postsecondary Institution  Percent
# 25  All Schools      215.0                       76.0    35.35
# 38  All Schools      125.0                       49.0    39.20
# 96  All Schools      155.0                       65.0    41.94
# 68  All Schools      223.0                       95.0    42.60
# 43  All Schools       92.0                       40.0    43.48

# %%
# Create checkpoint for cleaned performance metics dataframe
school_clean = school_no_TFS.copy()

# %%
# Export dataframe to csv
school_clean = school_no_TFS
school_clean.to_csv('data_export/school_clean.csv',index=False)

# %%
import random
random_list = []
for index in range(school_sorted['School District Code'].count()):
    random_list.append(random.randrange(school_sorted['School District Code'].count()))
    
index_list = random_list[:100]

# %%
rand_school_data = school_sorted.iloc[index_list]
rand_school_data
# Out:
#      School Year School District Code     School District Name School Code  \
# 146         2017                  751             Wayne County         ALL
# 23          2017                  625  Savannah-Chatham County         ALL
# 99          2017                  702            Monroe County         ALL
# 25          2017                  627         Chattooga County         ALL
# 113         2017                  716           Pulaski County         ALL
# ..           ...                  ...                      ...         ...
# 59          2017                  662          Glascock County         ALL
# 121         2017                  725          Seminole County         ALL
# 142         2017                  747            Walton County         ALL
# 128         2017                  733            Taylor County         ALL
# 107         2017                  710          Paulding County         ALL
#
#      School Name  Graduates  Postsecondary Institution  Percent
# 146  All Schools      328.0                      176.0    53.66
# 23   All Schools     1865.0                     1158.0    62.09
# 99   All Schools      291.0                      201.0    69.07
# 25   All Schools      215.0                       76.0    35.35
# 113  All Schools       80.0                       54.0    67.50
# ..           ...        ...                        ...      ...
# 59   All Schools       40.0                       26.0    65.00
# 121  All Schools      109.0                       70.0    64.22
# 142  All Schools      878.0                      586.0    66.74
# 128  All Schools       81.0                       57.0    70.37
# 107  All Schools     1944.0                     1256.0    64.61
#
# [100 rows x 8 columns]

# %%
expenditure_data
# Out:
#        Unnamed: 0 SCHOOL_YEAR  School District Code   DISTRICT_NAME  \
# 0              17     2017-18                   601  Appling County
# 1              18     2017-18                   601  Appling County
# 2              19     2017-18                   601  Appling County
# 3              20     2017-18                   601  Appling County
# 4              21     2017-18                   601  Appling County
# ...           ...         ...                   ...             ...
# 28583       28600     2017-18                   759    Worth County
# 28584       28601     2017-18                   759    Worth County
# 28585       28602     2017-18                   759    Worth County
# 28586       28603     2017-18                   759    Worth County
# 28587       28604     2017-18                   759    Worth County
#
#       SCHOOL_CODE                  SCHOOL_NAME Revenues/Expenditures  \
# 0             ALL            All Column Values     K-12 Expenditures
# 1             ALL            All Column Values     K-12 Expenditures
# 2             ALL            All Column Values     K-12 Expenditures
# 3             ALL            All Column Values     K-12 Expenditures
# 4             ALL            All Column Values     K-12 Expenditures
# ...           ...                          ...                   ...
# 28583        0196  Worth County Primary School     K-12 Expenditures
# 28584        0196  Worth County Primary School     K-12 Expenditures
# 28585        0196  Worth County Primary School     K-12 Expenditures
# 28586        0196  Worth County Primary School     K-12 Expenditures
# 28587        0196  Worth County Primary School     K-12 Expenditures
#
#                            Description  REV_EXP_VALUE  Dollars per FTE
# 0                        Debt Services           0.00             0.00
# 1               General Administration      839011.19           240.89
# 2                          Instruction    21602137.39          6202.16
# 3                Instructional Support     1405654.54           403.58
# 4           Maintenance and Operations     2388308.23           685.70
# ...                                ...            ...              ...
# 28583                   Pupil Services      308906.85           432.64
# 28584  Renovation and Capital Projects           0.00             0.00
# 28585            School Administration      403012.06           564.44
# 28586             School food Services           0.00             0.00
# 28587                   Transportation           0.00             0.00
#
# [28588 rows x 10 columns]

# %%
expenditure_data
clean_expe_df = expenditure_data.loc[(expenditure_data["SCHOOL_NAME"] == "All Column Values")]

# %%
deletecolumns = ["School Year", "School District Name", "School Code", "School Name"]
rand_school_data_df1 = rand_school_data.drop(deletecolumns, 1)
rand_school_data_df1
# Out:
#     School District Code  Graduates  Postsecondary Institution  Percent
# 146                  751      328.0                      176.0    53.66
# 23                   625     1865.0                     1158.0    62.09
# 99                   702      291.0                      201.0    69.07
# 25                   627      215.0                       76.0    35.35
# 113                  716       80.0                       54.0    67.50
# ..                   ...        ...                        ...      ...
# 59                   662       40.0                       26.0    65.00
# 121                  725      109.0                       70.0    64.22
# 142                  747      878.0                      586.0    66.74
# 128                  733       81.0                       57.0    70.37
# 107                  710     1944.0                     1256.0    64.61
#
# [100 rows x 4 columns]

# %%
merged_expenditure = pd.merge(clean_expe_df, rand_school_data_df1)
merged_expenditure
# Out:
#       Unnamed: 0 SCHOOL_YEAR School District Code   DISTRICT_NAME SCHOOL_CODE  \
# 0             17     2017-18                  601  Appling County         ALL
# 1             18     2017-18                  601  Appling County         ALL
# 2             19     2017-18                  601  Appling County         ALL
# 3             20     2017-18                  601  Appling County         ALL
# 4             21     2017-18                  601  Appling County         ALL
# ...          ...         ...                  ...             ...         ...
# 1678       28547     2017-18                  759    Worth County         ALL
# 1679       28548     2017-18                  759    Worth County         ALL
# 1680       28548     2017-18                  759    Worth County         ALL
# 1681       28549     2017-18                  759    Worth County         ALL
# 1682       28549     2017-18                  759    Worth County         ALL
#
#             SCHOOL_NAME Revenues/Expenditures                 Description  \
# 0     All Column Values     K-12 Expenditures               Debt Services
# 1     All Column Values     K-12 Expenditures      General Administration
# 2     All Column Values     K-12 Expenditures                 Instruction
# 3     All Column Values     K-12 Expenditures       Instructional Support
# 4     All Column Values     K-12 Expenditures  Maintenance and Operations
# ...                 ...                   ...                         ...
# 1678  All Column Values         K-12 Revenues               State Lottery
# 1679  All Column Values         K-12 Revenues                 State Other
# 1680  All Column Values         K-12 Revenues                 State Other
# 1681  All Column Values         K-12 Revenues                   State QBE
# 1682  All Column Values         K-12 Revenues                   State QBE
#
#       REV_EXP_VALUE  Dollars per FTE  Graduates  Postsecondary Institution  \
# 0              0.00             0.00      198.0                      118.0
# 1         839011.19           240.89      198.0                      118.0
# 2       21602137.39          6202.16      198.0                      118.0
# 3        1405654.54           403.58      198.0                      118.0
# 4        2388308.23           685.70      198.0                      118.0
# ...             ...              ...        ...                        ...
# 1678           0.00             0.00      204.0                      116.0
# 1679      427612.32           138.25      204.0                      116.0
# 1680      427612.32           138.25      204.0                      116.0
# 1681    18993326.00          6140.75      204.0                      116.0
# 1682    18993326.00          6140.75      204.0                      116.0
#
#       Percent
# 0       59.60
# 1       59.60
# 2       59.60
# 3       59.60
# 4       59.60
# ...       ...
# 1678    56.86
# 1679    56.86
# 1680    56.86
# 1681    56.86
# 1682    56.86
#
# [1683 rows x 13 columns]

# %%
def bar_graph(df, description ):
    instruction_df = df.loc[(merged_expenditure["Description"] == description)]
    instruction_df.drop_duplicates()
    z = (stats.zscore(instruction_df.loc[:,"Dollars per FTE"]))
    instruction_df.loc[:,(f'{description}_zscore')] = z
    instruction_df = instruction_df.loc[(instruction_df[f'{description}_zscore']<2) & (instruction_df[f'{description}_zscore']>-2)]
    x_values = instruction_df['Dollars per FTE']
    y_values = instruction_df['Percent']
    plt.scatter(x_values,y_values)
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.xlabel(f"{description}")
    plt.ylabel('% of Graduates into College')
    plt.title(f"{description} vs. Into College ")
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(20,15),fontsize=15,color="red")
    print(f"The r-value is: {rvalue**2}")
    plt.show()
            
merged_expenditure['Description'].unique()
# Out:
# array(['Debt Services', 'General Administration', 'Instruction',
#        'Instructional Support', 'Maintenance and Operations', 'Media',
#        'Pupil Services', 'Renovation and Capital Projects',
#        'School Administration', 'School food Services', 'Transportation',
#        'Federal', 'Local', 'Other', 'State Lottery', 'State Other',
#        'State QBE'], dtype=object)

# %%
description_list = merged_expenditure['Description'].unique()
description_list
# Out:
# array(['Debt Services', 'General Administration', 'Instruction',
#        'Instructional Support', 'Maintenance and Operations', 'Media',
#        'Pupil Services', 'Renovation and Capital Projects',
#        'School Administration', 'School food Services', 'Transportation',
#        'Federal', 'Local', 'Other', 'State Lottery', 'State Other',
#        'State QBE'], dtype=object)

# %%
for description in description_list:
    bar_graph(merged_expenditure,description)
# Out:
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.02823280545545384
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.0006308136401691629
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.09256331056434262
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.00010037119170489927
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.09538989310007472
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.007367442583603458
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 2.0470806012030197e-08
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.0008340429728876576
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.0011814294510417748
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.030768975268225
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.002520024162721905
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.007354951821737528
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.08487083668354756
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# The r-value is: 0.04050057245154526
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\Tako\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-388296aea41a> in <module>
#       1 for description in description_list:
# ----> 2     bar_graph(merged_expenditure,description)
#
# <ipython-input-24-f6367b7224e4> in bar_graph(df, description)
#       8     y_values = instruction_df['Percent']
#       9     plt.scatter(x_values,y_values)
# ---> 10     (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
#      11     regress_values = x_values * slope + intercept
#      12     line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
#
# ~\anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     134
#     135     if x.size == 0 or y.size == 0:
# --> 136         raise ValueError("Inputs must not be empty.")
#     137
#     138     n = len(x)
#
# ValueError: Inputs must not be empty.

# %% [markdown]
# # Conclusion
#
# ## there is a negative correlation on Transportation expenditure vs graduation rate
# ## there is a positive correlation on Instruction expenditure vs graduation rate
