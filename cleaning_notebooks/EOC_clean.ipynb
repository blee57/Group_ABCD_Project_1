# %%
import pandas as pd

# %%
df_eoc = pd.read_csv('../dataset/EOC_2019_By_Grad_FEB_24_2020 (1).csv')
# Out:
# C:\Users\hsueh\Conda\envs\PythonEnv3.9\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_id_subgroup = df_eoc.groupby(['SCHOOL_DISTRCT_CD', 'SUBGROUP_NAME']).mean().reset_index()
df_id_sub_noall = df_id_subgroup.loc[df_id_subgroup['SUBGROUP_NAME'] != 'All Students']

# %%
subgroup_clean = df_id_sub_noall.rename(columns=
    {
        'SCHOOL_DISTRCT_CD' : 'School District Code'
    }
)

# %%
subgroup_clean.to_csv('../data_export/subgroup_EOC.csv')

# %%
df_id_type = df_eoc.groupby(['SCHOOL_DISTRCT_CD', 'TEST_CMPNT_TYP_NM']).mean().reset_index()

# %%
df_id_type
# Out:
#      SCHOOL_DISTRCT_CD                     TEST_CMPNT_TYP_NM  ACDMC_LVL  \
# 0                  601  9th Grade Literature and Composition   9.400000
# 1                  601                             Algebra I   9.640000
# 2                  601   American Literature and Composition  10.684211
# 3                  601                               Biology   9.562500
# 4                  601    Economics/Business/Free Enterprise  11.785714
# ...                ...                                   ...        ...
# 1634               ALL                    Coordinate Algebra   9.635294
# 1635               ALL    Economics/Business/Free Enterprise   9.827586
# 1636               ALL                              Geometry   9.897727
# 1637               ALL                      Physical Science   9.921348
# 1638               ALL                            US History  10.528571
#
#       BEGIN_PCT  DEVELOPING_PCT  PROFICIENT_PCT  DISTINGUISHED_PCT
# ...

# %%
type_clean = df_id_type.copy()

# %%
type_clean.to_csv('../data_export/type_group_EOC.csv')
