# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import/read Excel file
gender_data = 'gender-grad-data.xlsx'

# Convert to DataFrame for gender
gender_df = pd.read_excel(gender_data)
gender_df.head()
# Out:
#    School Year School District Code School District Name School Code  \
# 0         2017                  601       Appling County         ALL
# 1         2017                  602      Atkinson County         ALL
# 2         2017                  603         Bacon County         ALL
# 3         2017                  604         Baker County         ALL
# 4         2017                  605       Baldwin County         ALL
#
#    School Name  Total High School Graduates  \
# 0  All Schools                        198.0
# 1  All Schools                         97.0
# 2  All Schools                        118.0
# 3  All Schools                         18.0
# 4  All Schools                        271.0
#
#    Number of High School Graduates Enrolled in Postsecondary Institution  \
# 0                                              118.0
# 1                                               60.0
# 2                                               66.0
# ...

# %%
# Clean data- remove TFS
gender_clean_df=gender_df.dropna()
gender_clean_df
# Out:
#      School Year School District Code School District Name School Code  \
# 0           2017                  601       Appling County         ALL
# 1           2017                  602      Atkinson County         ALL
# 2           2017                  603         Bacon County         ALL
# 4           2017                  605       Baldwin County         ALL
# 5           2017                  606         Banks County         ALL
# ..           ...                  ...                  ...         ...
# 183         2017                  789     Thomasville City         ALL
# 184         2017                  791           Trion City         ALL
# 185         2017                  792        Valdosta City         ALL
# 186         2017                  793         Vidalia City         ALL
# 190         2017                  ALL          All Systems         ALL
#
#      School Name  Total High School Graduates  \
# 0    All Schools                        198.0
# ...
